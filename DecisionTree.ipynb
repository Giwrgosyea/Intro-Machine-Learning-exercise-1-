# %%
##Decision Tree

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn import tree
from matplotlib import pyplot as plt

# %%
dataset_url = 'http://mlr.cs.umass.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'
data = pd.read_csv(dataset_url, sep=';')

# %%
print data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
##get quality
y = data.quality
#print y

# %%
##get features 
x = data.drop('quality', axis=1)
#print x

# %%
#should you split in train and test?
##Tree
clf=tree.DecisionTreeClassifier(max_depth=5)
clf.fit(x,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
##print tree
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None) 
graph = graphviz.Source(dot_data)  
graph

# %%
imp = clf.feature_importances_
print imp
# Out:
# [ 0.00992062  0.07402069  0.01751206  0.06179312  0.00297656  0.06305766
#   0.12126522  0.0096937   0.05195554  0.16374708  0.42405775]

# %%
name_list = data.columns[:-1]
# Sort by the importance
imp, name_list = zip(*sorted(zip(imp, name_list)))
y_pos = np.arange(len(name_list))

#print(name_list)
#print(y_pos)

print "2 most important: " ,name_list[len(name_list)-1] , name_list[len(name_list)-2]
# Out:
# 2 most important:  alcohol sulphates
